# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[3.4,5.5,6.7]
plt.scatter(x,y)
plt.show()

# %%
x=[1,2,3]
y=[3.4,5.5,6.7]
plt.scatter(x,y)
plt.title("Scatter Plot")
plt.xlabel("Days")
plt.ylabel("No")
plt.show()
