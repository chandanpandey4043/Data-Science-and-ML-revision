# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no)
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black")
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",cumulative=-1,edgecolor="black")
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",bottom=30)
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",histtype="step")
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",histtype="stepfilled")
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",histtype="barstacked")
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",histtype="barstacked",orientation="horizontal")
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",histtype="barstacked",rwidth=0.7)
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",histtype="barstacked",rwidth=0.7,log=True)
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.show()

# %%
import matplotlib.pyplot as plt
no=[49,45,41,12,25,45,23,12,34,56,78,43,56,71,23,43,65,43,33,31,63,75]
plt.hist(no,color="green",edgecolor="black",histtype="barstacked",rwidth=0.7)
plt.title("view")
plt.xlabel("Data Presentation")
plt.ylabel("Show")
plt.axvline(50,color="red")
plt.grid()
plt.show()
